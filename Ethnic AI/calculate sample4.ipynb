# %%
 
print("Welcome to Wills Tech calculation Sample.")
name=input("What is your name:")
print("Hello ",name,"\nOnce again welcome to wills tech calculation sample")
print("I hope you enjoy yourselve and give a feedback .\n")

#operation mode
opeartion_mode=input("Which can of operation to you want to perform:\n1.addition (+) \n2.subtraction(-) \n3.multiplication(*)\n4.division(/) \n5.power(**)\n6.floor(//) \n7.square of a number \n8.square root of a number\n:")

#function of the operation modes
    
def opeartion(x=0,y=0, z=0):
    try:
        if opeartion_mode =="addition" or opeartion_mode =="+" or opeartion_mode =="Additon" or opeartion_mode=="1":
            x=int(input("Please enter your  first number to add:\n=>"))
            y=int(input("Please enter the second number to add:\n=>"))
            print("The sum of ",x,"and ",y ,"is",x+y)

        elif opeartion_mode =="subtraction" or opeartion_mode =="-" or opeartion_mode =="Subtraction" or opeartion_mode =="2":
            x=int(input("Please enter the first number to subtract:\n"))
            y=int(input("please enter the second number to subtract:\n"))
            print("The different between",x,"and ",y ,"is",x-y)
                
        elif opeartion_mode =="multiplication" or opeartion_mode =="*" or opeartion_mode =="Multiplication" or opeartion_mode =="3":
            x=int(input("Please enter the first number to multiply:\n=>"))
            y=int(input("Please enter the second number to multiply:\n=>"))
            print("The product of ",x,"and ",y ,"is",x*y)
                
        elif opeartion_mode =="division" or opeartion_mode =="/" or opeartion_mode =="Division" or opeartion_mode =="4":
            x=int(input("Please enter the first number to divide:\n=>"))
            y=int(input("Please enter the second number to divide:\n=>"))
            print("The divsion of ",x,"and ",y ,"is",x/y)

        elif opeartion_mode =="power" or opeartion_mode =="**" or opeartion_mode =="Power" or opeartion_mode =="5":
            x=int(input("Please enter the first number to power:\n=>"))
            y=int(input("Please enter the second number to power:\n=>"))
            print("The power  of ",x,"and ",y ,"is",x**y)

        elif opeartion_mode =="floor" or opeartion_mode =="//" or opeartion_mode =="Floor" or opeartion_mode =="6":
            x=int(input("Please enter the first number to division:\n=>"))
            y=int(input("Please enter the second number to division:\n=>"))
            print("The floor value of ",x,"and ",y ,"is",x//y)

        elif opeartion_mode =="square" or opeartion_mode =="7" or opeartion_mode =="Square":
            x=int(input("Please enter the  number to square:\n=>"))
            print("The sqaure of ",x,"is",x*x)

            
       
    except(ValueError,TypeError,NameError):
        print("please any key to exit:")
    
opeartion()
# Out:
# Welcome to Wills Tech calculation Sample.
# What is your name:wiaslasl
# Hello  wiaslasl
# Once again welcome to wills tech calculation sample
# I hope you enjoy yourselve and give a feedback .
#
# Which can of operation to you want to perform:
# 1.addition (+)
# 2.subtraction(-)
# 3.multiplication(*)
# 4.division(/)
# 5.power(**)
# 6.floor(//)
# 7.square of a number
# 8.square root of a number
# :1

# %%
# another way

print("Welcome to Wills Tech calculation Sample.")
name = input("What is your name: ")
print("Hello", name, "\nOnce again welcome to Wills Tech calculation sample")
print("I hope you enjoy yourself and give a feedback.\n")


# operation mode
operation_mode = input("Which type of operation do you want to perform:\n1. Addition (+)\n2. Subtraction (-)\n3. Multiplication (*)\n4. Division (/)\n5. Power (**)\n6. Floor Division (//)\n7. Square of a Number\n8. Square Root of a Number\n")

# function of the operation modes
def operation(x=0, y=0):
    if operation_mode.lower in ["addition", "+", "1"]:
        x = int(input("Please enter the first number to add: "))
        y = int(input("Please enter the second number to add: "))
        print("The sum of", x, "and", y, "is", x+y)

    elif operation_mode.lower() in ["subtraction", "-", "2"]:
        x = int(input("Please enter the first number to subtract: "))
        y = int(input("Please enter the second number to subtract: "))
        print("The difference between", x, "and", y, "is", x-y)
                
    elif operation_mode.lower() in ["multiplication", "*", "3"]:
        x = int(input("Please enter the first number to multiply: "))
        y = int(input("Please enter the second number to multiply: "))
        print("The product of", x, "and", y, "is", x*y)
                
    elif operation_mode.lower() in ["division", "/", "4"]:
        x = int(input("Please enter the first number to divide: "))
        y = int(input("Please enter the second number to divide: "))
        print("The division of", x, "and", y, "is", x/y)

    elif operation_mode.lower() in ["power", "**", "5"]:
        x = int(input("Please enter the base number: "))
        y = int(input("Please enter the exponent: "))
        print(x, "raised to the power of", y, "is", x**y)

    elif operation_mode.lower() in ["floor", "//", "6"]:
        x = int(input("Please enter the dividend: "))
        y = int(input("Please enter the divisor: "))
        print("The floor division of", x, "and", y, "is", x//y)

    elif operation_mode.lower() in ["square", "7"]:
        x = int(input("Please enter the number to square: "))
        print("The square of", x, "is", x**2)

    elif operation_mode.lower() in ["square root", "8"]:
        import math
        x = float(input("Please enter the number to find the square root: "))
        print("The square root of", x, "is", math.sqrt(x))
    
operation()

# %%
#another with loops
print("Welcome to Wills Tech calculation Sample.")
name = input("What is your name: ")
print("Hello", name, "\nOnce again welcome to Wills Tech calculation sample")
print("I hope you enjoy yourself and give a feedback.\n")

while True:
    # operation mode
    operation_mode = input("Which type of operation do you want to perform:\n1. Addition (+)\n2. Subtraction (-)\n3. Multiplication (*)\n4. Division (/)\n5. Power (**)\n6. Floor Division (//)\n7. Square of a Number\n8. Square Root of a Number\n if you want to quit press quit or q\n")

    # function of the operation modes
    
    def operation(x=0, y=0):
        try:
            if operation_mode.lower() in ["addition", "+", "1"]:
                x = int(input("Please enter the first number to add: "))
                y = int(input("Please enter the second number to add: "))
                print("The sum of", x, "and", y, "is", x+y)

            elif operation_mode.lower() in ["subtraction", "-", "2"]:
                x = int(input("Please enter the first number to subtract: "))
                y = int(input("Please enter the second number to subtract: "))
                print("The difference between", x, "and", y, "is", x-y)
                
            elif operation_mode.lower() in ["multiplication", "*", "3"]:
                x = int(input("Please enter the first number to multiply: "))
                y = int(input("Please enter the second number to multiply: "))
                print("The product of", x, "and", y, "is", x*y)
                
            elif operation_mode.lower() in ["division", "/", "4"]:
                x = int(input("Please enter the first number to divide: "))
                y = int(input("Please enter the second number to divide: "))
                print("The division of", x, "and", y, "is", x/y)

            elif operation_mode.lower() in ["power", "**", "5"]:
                x = int(input("Please enter the base number: "))
                y = int(input("Please enter the exponent: "))
                print(x, "raised to the power of", y, "is", x**y)

            elif operation_mode.lower() in ["floor", "//", "6"]:
                x = int(input("Please enter the dividend: "))
                y = int(input("Please enter the divisor: "))
                print("The floor division of", x, "and", y, "is", x//y)

            elif operation_mode.lower() in ["square", "7"]:
                x = int(input("Please enter the number to square: "))
                print("The square of", x, "is", x**2)

            elif operation_mode.lower() in ["square root", "8"]:
                import math
                x = float(input("Please enter the number to find the square root: "))
                print("The square root of", x, "is", math.sqrt(x))

        except (ValueError, TypeError, NameError):
            print("Invalid input. Please")
    if operation_mode.lower() in ["q", "quit"]:
        break
    operation()
